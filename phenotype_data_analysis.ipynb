# %%
import pandas as pd

# %%
file_path = "data/phenotype.csv"
df = pd.read_csv(file_path)
# Out:
# /var/folders/7k/xvqgnqvn78d16vz2xqslqmxc0000gn/T/ipykernel_18304/4109111359.py:2: DtypeWarning: Columns (0: qualifier, 1: onset, 2: sex, 3: modifier) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
df
# Out:
#         database_id                                   disease_name qualifier  \
# 0       OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 1       OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 2       OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 3       OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 4       OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# ...             ...                                            ...       ...
# 285593   ORPHA:1777                               Temtamy syndrome       NaN
# 285594   ORPHA:1777                               Temtamy syndrome       NaN
# 285595   ORPHA:1777                               Temtamy syndrome       NaN
# 285596   ORPHA:1777                               Temtamy syndrome       NaN
# 285597   ORPHA:1777                               Temtamy syndrome       NaN
#
# ...

# %%
df.shape
# Out:
# (285598, 12)

# %%
df.head()
# Out:
#    database_id                                   disease_name qualifier  \
# 0  OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 1  OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 2  OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 3  OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
# 4  OMIM:619340  Developmental and epileptic encephalopathy 96       NaN
#
#        hpo_id      reference evidence onset frequency  sex modifier aspect  \
# 0  HP:0011097  PMID:31675180      PCS   NaN       1/2  NaN      NaN      P
# 1  HP:0002187  PMID:31675180      PCS   NaN       1/1  NaN      NaN      P
# 2  HP:0001518  PMID:31675180      PCS   NaN       1/2  NaN      NaN      P
# 3  HP:0032792  PMID:31675180      PCS   NaN       1/2  NaN      NaN      P
# 4  HP:0011451  PMID:31675180      PCS   NaN       1/2  NaN      NaN      P
#
#                  biocuration
# 0  HPO:probinson[2021-06-21]
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 285598 entries, 0 to 285597
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   database_id   285598 non-null  str
#  1   disease_name  285598 non-null  str
#  2   qualifier     727 non-null     str
#  3   hpo_id        285598 non-null  str
#  4   reference     285598 non-null  str
#  5   evidence      285598 non-null  str
#  6   onset         3052 non-null    str
#  7   frequency     221921 non-null  str
#  8   sex           640 non-null     str
#  9   modifier      1028 non-null    str
#  10  aspect        285598 non-null  str
#  11  biocuration   285598 non-null  str
# dtypes: str(12)
# memory usage: 26.1 MB

# %%
df.describe()
# Out:
#         database_id    disease_name qualifier      hpo_id  \
# count        285598          285598       727      285598
# unique        12956           12534         1       11645
# top     OMIM:618505  Sotos syndrome       NOT  HP:0000007
# freq            234             245       727        4288
#
#                      reference evidence       onset   frequency   sex  \
# count                   285598   285598        3052      221921   640
# unique                   22735        3          17        2332     4
# top     ISBN-13:978-0721606156      TAS  HP:0003577  HP:0040283  MALE
# freq                       230   136275         892       45216   448
#
#           modifier  aspect                  biocuration
# count         1028  285598                       285598
# unique          54       5                        12060
# top     HP:0012825       P  ORPHA:orphadata[2026-06-23]
# freq           360  267782                       115875

# %%
df.isnull().sum()
# Out:
# database_id          0
# disease_name         0
# qualifier       284871
# hpo_id               0
# reference            0
# evidence             0
# onset           282546
# frequency        63677
# sex             284958
# modifier        284570
# aspect               0
# biocuration          0
# dtype: int64

# %%
df.isnull().mean() * 100
# Out:
# database_id      0.000000
# disease_name     0.000000
# qualifier       99.745446
# hpo_id           0.000000
# reference        0.000000
# evidence         0.000000
# onset           98.931365
# frequency       22.296024
# sex             99.775909
# modifier        99.640054
# aspect           0.000000
# biocuration      0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(32)
